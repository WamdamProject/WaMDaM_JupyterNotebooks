# %% [markdown]
# ## Step 4: Create scenarios and download them into WaMDaM
#
# ### By Adel M. Abdallah, Utah State University, Feb 2019

# %% [markdown]
# ## Create new WEAP Scenarios in OpenAgua

# %% [markdown]
# * In OpenAgua, Go to the Bear River Network in the WEAP model project.
# * Click at the Scenario Icon on the left bar.
# * Click "Add Scenario". Define two new scenarios that are children of the Parent base scenario "Bear River WEAP Model 2017: Cons25PercCacheUrbWaterUse and Incr25PercCacheUrbWaterUse (Figure 1)
#
# * Repeate the same steps for the WASH model with the scnearios names: ConsDemand and IncrDemand
#
# * Next, you will edit input data for each scenario that changes the demand for conservation and growth cases.(see below)
#
# <img src="https://github.com/WamdamProject/WaMDaM-software-ecosystem/blob/master/mkdocs/Edit_MD_Files/images/Add_Scenarios.PNG?raw=true" style="float:center;width:600px;padding:20px">
# <h3><center>**Figure 1:** Add new scenarios </center></h3>

# %% [markdown]
# * In the WASH Model, we will change input data for three demand sites: Logan Potable, North Cache Potable, and South Cache Potable which are for Cache County urban demand. Its attribute called : Monthly Demand_Se
#
# * Use the drop down menu in OpenAgua to the right top corner to swith bewtween scenarios.
# * For the Cons Demand scenario, we reduce demand by 25%. The easiest way to do it is to copy the OneYear base scenario demand into excel for all the months. Then create a formula to reduce demand by 25%. One way to do it is to get the 75% of the base demand which is like (=A1*.75)
#
# * Copy the new demand values and paste them into the Cons25PercCacheUrbWaterUse column. (Figure 2).
# * Do the same for the other scenario (Incr25PercCacheUrbWaterUse). But this time, increase it by 25% (like =A1*1.25)
# * Notice the autogenerated plot to the right and how the new scenarios are shifted up or down from the base scenario.
#
#
# <img src="https://github.com/WamdamProject/WaMDaM-software-ecosystem/blob/master/mkdocs/Edit_MD_Files/images/EditInput_WEAP.PNG?raw=true" style="float:center;width:600px;padding:20px">
# <h3><center>**Figure 2:** Edit demand data for each new scenario in WEAP</center></h3>

# %% [markdown]
# * In the WASH Model, we will change input data for the demand site clled "j3" which is for Cache County urban demand. Its attribute called : dReqBase.
# * Use the drop down menu in OpenAgua to the right top corner to swith bewtween scenarios.
# * For the Cons Demand scenario, we reduce demand by 25%. The easiest way to do it is to copy the OneYear base scenario demand into excel for all the months. Then create a formula to reduce demand by 25%. One way to do it is to get the 75% of the base demand which is like (=A1*.75)
# * Copy the new demand values and paste them into the ConsDemand column. (Figure 3).
# * Do the same for the other scenario (IncrDemand). But this time, increase it by 25% (like =A1*1.25)
# * Notice the autogenerated plot to the right and how the new scenarios are shifted up or down from the base scenario.
#
# <img src="https://github.com/WamdamProject/WaMDaM-software-ecosystem/blob/master/mkdocs/Edit_MD_Files/images/Edit_WASH.PNG?raw=true" style="float:center;width:600px;padding:20px">
# <h3><center>**Figure 3:** Edit demand data for each new scenario in WASH</center></h3>

# %% [markdown]
# # Congratualtions!
# * Now you have both WEAP and WASH models with two new scnearios each.
#
# * Next, we will use the WaMDaM Wizard to download them into a WaMDaM Excel Workbook and then into a SQLite database
#
# * We will also download a third model that is publically avialable in OpenAgua for Monterrey Mexico
