# %% [markdown]
# ## WaMDaM_Use_Case 3.1_Seasonal: What seasonal flow values to use at a site (e.g., below Steward Dam)?
#
# #### By Adel M. Abdallah, Utah State University, August 2018
#
#
# This notebook demonstrates basic WaMDaM use cases analysis using scientific Python libraries such as [pandas](https://pandas.pydata.org/) and [plotly](https://plot.ly/).  It reads WaMDaM SQLite data from a published HydroShare Generic Resource, runs SQL script, and them uses Python plotly to visualize the results
#
# This use case identifies five time series and seasonal flow data for the site below Stewart Dam, Idaho
#
# For more info: http://docs.wamdam.org/QuerySelect/use_case_3/#figure-2
#
#
# ### Steps to reproduce this use case results and plots
#
# 1.[Import python libraries](#Import)
#
#
# 2.[Connect to the WaMDaM populated SQLite file](#Connect)
#
#
# 3.[Query WaMDaM dababase for flow seasonal data](#QueryFlowSeasonal)
#
#
# 4.[Plot the seasonal figure](#Seasonal_13a)
#
#
# 5.[Query WaMDaM dababase for time series to create the (cumulative distribution function) CDF plot](#QueryTimeSeries)
#
# 6.[Plot the CDF figure ](#PlotCDF)
#
# 7.[Close the SQLite and WEAP API connections](#Close)

# %% [markdown]
# <a name="Import"></a>
# # 1. Import python libraries
# ### Install any missing ones you dont have. How? see at this link here
# https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/

# %%
# 1. Import python libraries 
### set the notebook mode to embed the figures within the cell

import plotly
plotly.__version__
import plotly.offline as offline
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
offline.init_notebook_mode(connected=True)
from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *

init_notebook_mode(connected=True)         # initiate notebook for offline plot

import os
import csv
from collections import OrderedDict
import sqlite3
import pandas as pd
import numpy as np
from IPython.display import display, Image, SVG, Math, YouTubeVideo
import urllib

print 'The needed Python libraries have been imported'
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# The needed Python libraries have been imported

# %% [markdown]
# <a name="Connect"></a>
# # 2. Connect to the WaMDaM populated SQLite file

# %%
# 2. Connect to the WaMDaM populated SQLite file 

# Then we can run queries against it within this notebook :)  

# the SQLite file is published here 
#https://github.com/WamdamProject/WaMDaM_UseCases/blob/master/UseCases_files/3SQLite_database/BearRiverDatasets_June_2018.sqlite

conn = sqlite3.connect('BearRiverDatasets_June_2018_Final.sqlite')

print 'Connected to the WaMDaM SQLite file called: BearRiverDatasets_June_2018_Final'
# Out:
# Connected to the WaMDaM SQLite file called: BearRiverDatasets_June_2018_Final

# %% [markdown]
# <a name="QueryFlowSeasonal"></a>
# # 3. Query WaMDaM dababase for flow seasonal data

# %%
# Use Case 3.1Identify_aggregate_TimeSeriesValues.csv
# plot aggregated to monthly and converted to acre-feet time series data of multiple sources



# 2.2Identify_aggregate_TimeSeriesValues.csv
Query_UseCase3_1_seasonal_URL="""
https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase3/UseCase3.1/3_Identify_SeasonalValues.sql

"""

# Read the query text inside the URL
Query_UseCase3_1_Seasonal_text = urllib.urlopen(Query_UseCase3_1_seasonal_URL).read()


# return query result in a pandas data frame
result_df_UseCase3_1_Seasonal= pd.read_sql_query(Query_UseCase3_1_Seasonal_text, conn)

# uncomment the below line to see the list of attributes
display (result_df_UseCase3_1_Seasonal)


# Save the datafrom as a csv file into the Jupyter notebook working space
result_df_UseCase3_1_Seasonal.to_csv('UseCases_Results_csv\UseCase3_1_Seasonal.csv', index = False)
# Out:
#    ResourceTypeAcronym            ScenarioName ObjectType  \
# 0     BearRiverWyoming     Bear Dry Year Model  Gage Node
# 1     BearRiverWyoming     Bear Dry Year Model  Gage Node
# 2     BearRiverWyoming     Bear Dry Year Model  Gage Node
# 3     BearRiverWyoming     Bear Dry Year Model  Gage Node
# 4     BearRiverWyoming     Bear Dry Year Model  Gage Node
# 5     BearRiverWyoming     Bear Dry Year Model  Gage Node
# 6     BearRiverWyoming     Bear Dry Year Model  Gage Node
# 7     BearRiverWyoming     Bear Dry Year Model  Gage Node
# 8     BearRiverWyoming     Bear Dry Year Model  Gage Node
# 9     BearRiverWyoming     Bear Dry Year Model  Gage Node
# 10    BearRiverWyoming     Bear Dry Year Model  Gage Node
# 11    BearRiverWyoming     Bear Dry Year Model  Gage Node
# 12    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 13    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 14    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 15    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 16    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 17    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 18    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 19    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 20    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 21    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 22    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 23    BearRiverWyoming  Bear Normal Year Model  Gage Node
# 24    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 25    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 26    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 27    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 28    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 29    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 30    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 31    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 32    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 33    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 34    BearRiverWyoming     Bear Wet Year Model  Gage Node
# 35    BearRiverWyoming     Bear Wet Year Model  Gage Node
#
#                  AttributeName AttributeNameCV InstanceName  \
# 0   Average Monthly Streamflow            Flow   Node 12.04
# 1   Average Monthly Streamflow            Flow   Node 12.04
# 2   Average Monthly Streamflow            Flow   Node 12.04
# 3   Average Monthly Streamflow            Flow   Node 12.04
# 4   Average Monthly Streamflow            Flow   Node 12.04
# 5   Average Monthly Streamflow            Flow   Node 12.04
# 6   Average Monthly Streamflow            Flow   Node 12.04
# 7   Average Monthly Streamflow            Flow   Node 12.04
# 8   Average Monthly Streamflow            Flow   Node 12.04
# 9   Average Monthly Streamflow            Flow   Node 12.04
# 10  Average Monthly Streamflow            Flow   Node 12.04
# 11  Average Monthly Streamflow            Flow   Node 12.04
# 12  Average Monthly Streamflow            Flow   Node 12.04
# 13  Average Monthly Streamflow            Flow   Node 12.04
# 14  Average Monthly Streamflow            Flow   Node 12.04
# 15  Average Monthly Streamflow            Flow   Node 12.04
# 16  Average Monthly Streamflow            Flow   Node 12.04
# 17  Average Monthly Streamflow            Flow   Node 12.04
# 18  Average Monthly Streamflow            Flow   Node 12.04
# 19  Average Monthly Streamflow            Flow   Node 12.04
# 20  Average Monthly Streamflow            Flow   Node 12.04
# 21  Average Monthly Streamflow            Flow   Node 12.04
# 22  Average Monthly Streamflow            Flow   Node 12.04
# 23  Average Monthly Streamflow            Flow   Node 12.04
# 24  Average Monthly Streamflow            Flow   Node 12.04
# 25  Average Monthly Streamflow            Flow   Node 12.04
# 26  Average Monthly Streamflow            Flow   Node 12.04
# 27  Average Monthly Streamflow            Flow   Node 12.04
# 28  Average Monthly Streamflow            Flow   Node 12.04
# 29  Average Monthly Streamflow            Flow   Node 12.04
# 30  Average Monthly Streamflow            Flow   Node 12.04
# 31  Average Monthly Streamflow            Flow   Node 12.04
# 32  Average Monthly Streamflow            Flow   Node 12.04
# 33  Average Monthly Streamflow            Flow   Node 12.04
# 34  Average Monthly Streamflow            Flow   Node 12.04
# 35  Average Monthly Streamflow            Flow   Node 12.04
#
#                                        InstanceNameCV SeasonName  SeasonOrder  \
# 0   USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Jan            1
# 1   USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Feb            2
# 2   USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Mar            3
# 3   USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Apr            4
# 4   USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        May            5
# 5   USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Jun            6
# 6   USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Jul            7
# 7   USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Aug            8
# 8   USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Sep            9
# 9   USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Oct           10
# 10  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Nov           11
# 11  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Dec           12
# 12  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Jan            1
# 13  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Feb            2
# 14  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Mar            3
# 15  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Apr            4
# 16  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        May            5
# 17  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Jun            6
# 18  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Jul            7
# 19  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Aug            8
# 20  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Sep            9
# 21  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Oct           10
# 22  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Nov           11
# 23  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Dec           12
# 24  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Jan            1
# 25  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Feb            2
# 26  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Mar            3
# 27  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Apr            4
# 28  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        May            5
# 29  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Jun            6
# 30  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Jul            7
# 31  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Aug            8
# 32  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Sep            9
# 33  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Oct           10
# 34  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Nov           11
# 35  USGS 10046500 BEAR RIVER BL STEWART DAM NR MON...        Dec           12
#
#    SeasonNumericValue
# 0       580.925619835
# 1       644.099173554
# 2       624.363636364
# 3       451.034710744
# 4       489.927548209
# 5       666.049586777
# 6       663.454545455
# 7        796.26446281
# 8       705.520661157
# 9       720.925619835
# 10      406.776859504
# 11       309.32231405
# 12      298.992605481
# 13      291.152675076
# 14      485.084993475
# 15      378.010961288
# 16      645.567638104
# 17      2506.33492823
# 18      1004.34623749
# 19      691.030882993
# 20      949.184862984
# 21      658.515528491
# 22      513.009134406
# 23      422.406263593
# 24      188.033057851
# 25      200.925619835
# 26      494.876033058
# 27      429.818181818
# 28      1083.57024793
# 29      17187.4380165
# 30      13761.5867769
# 31      639.867768595
# 32      741.619834711
# 33      511.272727273
# 34      384.462809917
# 35      314.380165289

# %% [markdown]
# <a name="Seasonal_13a"></a>
# # 4. Plot the seasonal figure
#
#
#
# #### Reproduce this plot [Figure 13-A] in the WaMDaM paper
#
#
# <img src="https://github.com/WamdamProject/WaMDaM_UseCases/raw/master/UseCases_files/8Figures_jpg/UseCase3.1_seasonal_a.png" width="800">

# %%
# Use Case 2.3Identify_SeasonalValues

# plot Seasonal data for multiple scenarios



import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from random import randint
import pandas as pd

## read the input data from GitHub csv file which is a direct query output
# 3.3Identify_SeasonalValues.csv 

df_Seasonal =result_df_UseCase3_1_Seasonal
#get the many curves by looking under "ScenarioName" column header. 
#Then plot Season name vs season value
column_name = "ScenarioName"
subsets = df_Seasonal.groupby(column_name)

data = []


#for each subset (curve), set up its legend and line info manually so they can be edited
subsets_settings = {
    'Bear Wet Year Model': {
        'dash': 'solid',
         'mode':'lines+markers',
        'width':'4',
        'legend_index': 0,
        'legend_name': 'Wet Year Model',
         'color':'rgb(41, 10, 216)'
        },

    'Bear Normal Year Model': { # this oone is the name of subset as it appears in the csv file
        'dash': 'solid',     # this is properity of the line (curve)
        'width':'4',
        'mode':'lines+markers',
        'legend_index': 1,   # to order the legend
        'legend_name': 'Normal Year Model',  # this is the manual curve name 
         'color':'rgb(38, 77, 255)'

        },
    'Bear Dry Year Model': {
        'dash': 'solid',
        'mode':'lines+markers',
         'width':'4',
        'legend_index': 2,
        'legend_name': 'Dry Year Model',
         'color':'rgb(63, 160, 255)'
        },


        }


# This dict is used to map legend_name to original subset name
subsets_names = {y['legend_name']: x for x,y in subsets_settings.iteritems()}


for subset in subsets.groups.keys():
    print subset
    dt = subsets.get_group(name=subset)
    s = go.Scatter(
                    x=df_Seasonal.SeasonName,
                    y=dt['SeasonNumericValue'],
                    name = subsets_settings[subset]['legend_name'],
                    line = dict(
                        color =subsets_settings[subset]['color'],
                        width =subsets_settings[subset]['width'],
                        dash=subsets_settings[subset]['dash']
                                ),
                    marker=dict(size=10),            
                    opacity = 0.8
                   )
    data.append(s)
    
    
# Legend is ordered based on data, so we are sorting the data based 
# on desired legend order indicarted by the index value entered above
data.sort(key=lambda x: subsets_settings[subsets_names[x['name']]]['legend_index'])

    

layout = dict(
    #title = "Use Case 3.3",
    yaxis = dict(
        title = "Cumulative flow <br> (acre-feet/month)",
        tickformat= ',',
        showline=True,
        dtick='5000',
        ticks='outside',
        ticklen=10

                ),
    
    xaxis = dict(
        #title = "Month",
        ticks='inside',

        ticklen=25
                    ),
    legend=dict(
        x=0.6,y=0.5,
          bordercolor='#00000',
            borderwidth=2
               ),
    width=1200,
    height=800,
    #paper_bgcolor='rgb(233,233,233)',
    #plot_bgcolor='rgb(233,233,233)',
    margin=go.Margin(l=260,b=100),
    font=dict(size=35)
             )
# create a figure object
fig = dict(data=data, layout=layout)
#py.iplot(fig, filename = "2.3Identify_SeasonalValues") 


## it can be run from the local machine on Pycharm like this like below
## It would also work here offline but in a seperate window  
offline.iplot(fig,filename = 'UseCase3.1_seasonal_a',image='png' )       


###########################################################################################################
# Have you encounterd the messages below? if not, dont worry about it
# ----------------------------------------------
# Javascript error adding output!
# ReferenceError: Plotly is not defined
# See your browser Javascript console for more details.
# ----------------------------------------------

# Do the follwoing:

# Kernel -> Restart -> Clear all outputs and restart
# Save
# Close browser
# Open browser and run again
# Out:
# Bear Normal Year Model
# Bear Dry Year Model
# Bear Wet Year Model
# <div id="b84655b6-623c-4034-8d99-c1afb393b8f6" style="height: 800px; width: 1200px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b84655b6-623c-4034-8d99-c1afb393b8f6", [{"opacity": 0.8, "name": "Wet Year Model", "marker": {"size": 10}, "y": ["188.033057851", "200.925619835", "494.876033058", "429.818181818", "1083.57024793", "17187.4380165", "13761.5867769", "639.867768595", "741.619834711", "511.272727273", "384.462809917", "314.380165289"], "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec", "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec", "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "line": {"dash": "solid", "width": "4", "color": "rgb(41, 10, 216)"}, "type": "scatter"}, {"opacity": 0.8, "name": "Normal Year Model", "marker": {"size": 10}, "y": ["298.992605481", "291.152675076", "485.084993475", "378.010961288", "645.567638104", "2506.33492823", "1004.34623749", "691.030882993", "949.184862984", "658.515528491", "513.009134406", "422.406263593"], "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec", "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec", "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "line": {"dash": "solid", "width": "4", "color": "rgb(38, 77, 255)"}, "type": "scatter"}, {"opacity": 0.8, "name": "Dry Year Model", "marker": {"size": 10}, "y": ["580.925619835", "644.099173554", "624.363636364", "451.034710744", "489.927548209", "666.049586777", "663.454545455", "796.26446281", "705.520661157", "720.925619835", "406.776859504", "309.32231405"], "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec", "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec", "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "line": {"dash": "solid", "width": "4", "color": "rgb(63, 160, 255)"}, "type": "scatter"}], {"yaxis": {"ticks": "outside", "tickformat": ",", "title": "Cumulative flow <br> (acre-feet/month)", "ticklen": 10, "dtick": "5000", "showline": true}, "height": 800, "width": 1200, "xaxis": {"ticklen": 25, "ticks": "inside"}, "font": {"size": 35}, "margin": {"b": 100, "l": 260}, "legend": {"bordercolor": "#00000", "y": 0.5, "borderwidth": 2, "x": 0.6}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('b84655b6-623c-4034-8d99-c1afb393b8f6');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('png', 600, 800, 'UseCase3.1_seasonal_a');}}</script>

# %% [markdown]
# <a name="QueryTimeSeries"></a>
# # 5. Query WaMDaM dababase for time series to create the (cumulative distribution function) CDF plot

# %%
# Use Case 3.1Identify_aggregate_TimeSeriesValues.csv
# plot aggregated to monthly and converted to acre-feet time series data of multiple sources



# 2.2Identify_aggregate_TimeSeriesValues.csv
Query_UseCase3_1_URL="""
https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase3/UseCase3.1/2_Identify_aggregate_TimeSeriesValues.sql
"""

# Read the query text inside the URL
Query_UseCase3_1_text = urllib.urlopen(Query_UseCase3_1_URL).read()


# return query result in a pandas data frame
result_df_UseCase3_1= pd.read_sql_query(Query_UseCase3_1_text, conn)
df_TimeSeries=result_df_UseCase3_1
# uncomment the below line to see the list of attributes
# display (result_df_required)


# Save the datafrom as a csv file into the Jupyter notebook working space
result_df_UseCase3_1.to_csv('UseCases_Results_csv\UseCase3_1.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-8-b8d50b963f0a> in <module>()
#      14
#      15 # return query result in a pandas data frame
# ---> 16 result_df_UseCase3_1= pd.read_sql_query(Query_UseCase3_1_text, conn)
#      17 df_TimeSeries=result_df_UseCase3_1
#      18 # uncomment the below line to see the list of attributes
#
# C:\Users\Adel\AppData\Roaming\Python\Python27\site-packages\pandas\io\sql.pyc in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330     return pandas_sql.read_query(
#     331         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 332         parse_dates=parse_dates, chunksize=chunksize)
#     333
#     334
#
# C:\Users\Adel\AppData\Roaming\Python\Python27\site-packages\pandas\io\sql.pyc in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1437
#    1438         args = _convert_params(sql, params)
# -> 1439         cursor = self.execute(*args)
#    1440         columns = [col_desc[0] for col_desc in cursor.description]
#    1441
#
# C:\Users\Adel\AppData\Roaming\Python\Python27\site-packages\pandas\io\sql.pyc in execute(self, *args, **kwargs)
#    1397             cur = self.con
#    1398         else:
# -> 1399             cur = self.con.cursor()
#    1400         try:
#    1401             if kwargs:
#
# ProgrammingError: Cannot operate on a closed database.

# %% [markdown]
# <a name="PlotCDF"></a>
# # 6. Plot the CDF figure
#
#
# #### Reproduce this plot [Figure 13-B] in the WaMDaM paper
#
#
# <img src="https://github.com/WamdamProject/WaMDaM_UseCases/raw/master/UseCases_files/8Figures_jpg/UseCase3.1_seasonal_b.png" width="800">

# %%
# Use Case 2.4_plotcdf 

# plot Cumulative flow for June for the UDWR dataset. 
# Then get the percentage of time it exceeds dry and wet years 

# Adel Abdallah
# Dec 2, 2017


import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import scipy
import pandas as pd

## read the input data from GitHub csv file which is a direct query output for this  query:
# 3.2Identify_aggregate_TimeSeriesValues.sql

# Convert CalenderYear column data type to datetime
df_TimeSeries['CalenderYear'] = pd.to_datetime(df_TimeSeries['CalenderYear'], errors='coerce')

# Slice rows based on DatasetAcronym column
subsets = df_TimeSeries.groupby('ResourceTypeAcronym')

# Select rows where DatasetAcronym is UDWRFlowData
dt = subsets.get_group(name='UDWRFlowData')

# From the selected rows, select rows where month is June
specific_month = dt.CalenderYear.dt.month == 6

# CumulativeMonthly data of the desired DatasetAcronym name and month
cumulative_monthly = dt[specific_month].CumulativeMonthly.values.tolist()

# Sort cumulative_monthly in ascending order
cumulative_monthly.sort()

# Save the filtered data to csv, CumulativeMonthly and CalenderYear columns
filtered_data = dt[specific_month][['CumulativeMonthly', 'CalenderYear']]
filtered_data.to_csv('Filtered Data.csv', index=False)


# Create the y-axis list, which should be same length as x-axis and range
# from 0 to 1, to represent probability and have equal spacing between it's
# numbers, so we create a list of floats starting from 1 to length of
# cumsum(which represents the x-axis) + 1, (+1) because we started from 1 not 0,
# we want the same length of cumsum, and we are dividing the list by length of
# cumsum to produce the desired probability values, So the last number in the
# list should be equal to the length of cumsum, so that when we divide both
# both values we get 1.
# To get the last number equal length of cumsum, we have to use
# max range = len(cumsum)+1, because np.arange will stop before
# the maximum number, so it will stop at len(cumsum)
probability = np.arange(1.0, len(cumulative_monthly)+1) /len(cumulative_monthly) # 1.0 to make it float

data = []
# just plot the sorted_data array against the number of items smaller 
# than each element in the array 

cdf = go.Scatter(
    x = cumulative_monthly,
    y = probability,
        showlegend=True,
name='UDWR from 1923 to 2014',
    marker = dict(
        color='rgb(0, 0, 0)'
        )
    )

cdfdata=pd.DataFrame(data=dict(probability=probability,cumulative_monthly=cumulative_monthly))

data.append(cdf)


# Save the filtered data to csv, CumulativeMonthly and probability columns
filtered_data = cdfdata
filtered_data.to_csv('CDF_data.csv', index=False)
display (filtered_data)

# cdfdata

lowerthanDry=cdfdata.loc[cdfdata['cumulative_monthly'] <= 666, 'probability']
print 'lowerthanDry='
print lowerthanDry

UpperthanNormal=cdfdata.loc[cdfdata['cumulative_monthly'] >= 2506, 'probability']
print 'UpperthanNormal='
print UpperthanNormal

UpperthanWet=cdfdata.loc[cdfdata['cumulative_monthly'] >= 17181, 'probability']
print 'UpperthanWet='
print UpperthanWet



# vertical line dry year 
dry = go.Scatter(
    x=[666, 666 ],
    y=[0, 0.48],
    mode='lines',
        name='Dry year scenario <br> (BRSDM model)',
    hoverinfo='dry',
    showlegend=True,
    line=dict(
        shape='vh',
        width='4',
        dash = 'dot',
        color = '#3FA0FF'
            )
                    )
data.append(dry)



# horizontal line dry year 
dryHo = go.Scatter(
    x=[0, 666 ],
    y=[0.48, 0.48],
    mode='lines',
        name='Dry year scenario <br> (BRSDM model)',
    hoverinfo='dry',
    showlegend=False,
    line=dict(
        shape='vh',
        width='4',
        dash = 'dot',
        color = '#3FA0FF'
            )
                    )
data.append(dryHo)
# ------------------------------------------------------------


# vertical line normal year 
normal = go.Scatter(
    x=[2506, 2506],
    y=[0, 0.844],
    mode='lines',
        name='Normal year scenario <br> (BRSDM model)',
    hoverinfo='wet',
    showlegend=True,
    line=dict(
        shape='vh',
        dash = 'dashdot',
        width='4',
        color = '#264DFF'
            )
                    )
data.append(normal)


# horizontal line normal year 
normalHo = go.Scatter(
    x=[0, 2506],
    y=[0.844, 0.844],
    mode='lines',
        name='Normal year scenario <br> (BRSDM model)',
    hoverinfo='wet',
    showlegend=False,
    line=dict(
        shape='vh',
        dash = 'dashdot',
        width='4',
        color = '#264DFF'
            )
                    )
data.append(normalHo)

# ------------------------------------------------------------


# vertical line wet year 
wet = go.Scatter(
    x=[17181, 17181],
    y=[0, 0.93],
    mode='lines',
        name='Wet year scenario <br> (BRSDM model)',
    hoverinfo='wet',
    showlegend=True,
    line=dict(
        shape='vh',
        dash = 'dash',
        width='4',
        color = '#290AD8'
            )
                    )
data.append(wet)


# horizontal line wet year 
wetHo = go.Scatter(
    x=[0, 17181],
    y=[0.93, 0.93],
    mode='lines',
        name='Wet year scenario <br> (BRSDM model)',
    hoverinfo='wet',
    showlegend=False,
    line=dict(
        shape='vh',
        dash = 'dash',
        width='4',
        color = '#290AD8'
            )
                    )
data.append(wetHo)




layout = go.Layout(
    xaxis = dict(
        title = "Cumulative flow for June <br> (acre-feet/month)",
        zeroline=True,
         #showline=True,
        tickformat= ',',
        dtick='10000',
        ticks='inside',
        ticklen=25,   
        range = ['0', '40000'],


            ),
    yaxis = dict(
                title = 'Cumulative probability',
                dtick='0.1',
                ticks='outside',
                ticklen=25,
#                 range = ['0', '1'],


             showline=True,
),
    font=dict(size=35,family='arial'),
    width=1100,
    height=800,
    margin=go.Margin(
        l=230,
        b=150       ),
    legend=dict(
        x=0.5,y=0.5,
            bordercolor='#00000',
            borderwidth=2, 
     font=dict(
            family='arial',
            size=35                    )           
    ),
 
        
        
        
    )

fig = dict(data=data, layout=layout)

offline.iplot(fig,filename = 'UseCase3.1_seasonal_b',image='png' )
# Out:
#     cumulative_monthly  probability
# 0                62.00     0.010870
# 1               119.00     0.021739
# 2               128.00     0.032609
# 3               147.00     0.043478
# 4               184.46     0.054348
# 5               204.30     0.065217
# 6               238.02     0.076087
# 7               264.20     0.086957
# 8               297.52     0.097826
# 9               297.52     0.108696
# 10              297.52     0.119565
# 11              301.00     0.130435
# 12              323.31     0.141304
# 13              337.00     0.152174
# 14              368.00     0.163043
# 15              379.00     0.173913
# 16              381.00     0.184783
# 17              391.00     0.195652
# 18              398.68     0.206522
# 19              399.00     0.217391
# 20              407.00     0.228261
# 21              413.99     0.239130
# 22              416.53     0.250000
# 23              437.36     0.260870
# 24              476.00     0.271739
# 25              480.00     0.282609
# 26              485.95     0.293478
# 27              493.00     0.304348
# 28              495.67     0.315217
# 29              528.00     0.326087
# ..                 ...          ...
# 62             1232.00     0.684783
# 63             1244.00     0.695652
# 64             1400.30     0.706522
# 65             1537.00     0.717391
# 66             1549.00     0.728261
# 67             1567.00     0.739130
# 68             1585.00     0.750000
# 69             1730.00     0.760870
# 70             1775.00     0.771739
# 71             1817.00     0.782609
# 72             1827.00     0.793478
# 73             1864.00     0.804348
# 74             2001.00     0.815217
# 75             2043.00     0.826087
# 76             2439.30     0.836957
# 77             2904.00     0.847826
# 78             3220.00     0.858696
# 79             3810.00     0.869565
# 80             7020.00     0.880435
# 81             7069.00     0.891304
# 82             8830.00     0.902174
# 83            11100.00     0.913043
# 84            12760.00     0.923913
# 85            21000.00     0.934783
# 86            24700.00     0.945652
# 87            24900.00     0.956522
# 88            31140.00     0.967391
# 89            31800.00     0.978261
# 90            42680.00     0.989130
# 91           117000.00     1.000000
#
# [92 rows x 2 columns]
# lowerthanDry=
# 0     0.010870
# 1     0.021739
# 2     0.032609
# 3     0.043478
# 4     0.054348
# 5     0.065217
# 6     0.076087
# 7     0.086957
# 8     0.097826
# 9     0.108696
# 10    0.119565
# 11    0.130435
# 12    0.141304
# 13    0.152174
# 14    0.163043
# 15    0.173913
# 16    0.184783
# 17    0.195652
# 18    0.206522
# 19    0.217391
# 20    0.228261
# 21    0.239130
# 22    0.250000
# 23    0.260870
# 24    0.271739
# 25    0.282609
# 26    0.293478
# 27    0.304348
# 28    0.315217
# 29    0.326087
# 30    0.336957
# 31    0.347826
# 32    0.358696
# 33    0.369565
# 34    0.380435
# 35    0.391304
# 36    0.402174
# 37    0.413043
# 38    0.423913
# 39    0.434783
# 40    0.445652
# 41    0.456522
# 42    0.467391
# 43    0.478261
# Name: probability, dtype: float64
# UpperthanNormal=
# 77    0.847826
# 78    0.858696
# 79    0.869565
# 80    0.880435
# 81    0.891304
# 82    0.902174
# 83    0.913043
# 84    0.923913
# 85    0.934783
# 86    0.945652
# 87    0.956522
# 88    0.967391
# 89    0.978261
# 90    0.989130
# 91    1.000000
# Name: probability, dtype: float64
# UpperthanWet=
# 85    0.934783
# 86    0.945652
# 87    0.956522
# 88    0.967391
# 89    0.978261
# 90    0.989130
# 91    1.000000
# Name: probability, dtype: float64
# <div id="f36bd84e-3092-45ff-b640-ee34867706f1" style="height: 800px; width: 1100px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f36bd84e-3092-45ff-b640-ee34867706f1", [{"showlegend": true, "name": "UDWR from 1923 to 2014", "marker": {"color": "rgb(0, 0, 0)"}, "y": [0.010869565217391304, 0.021739130434782608, 0.03260869565217391, 0.043478260869565216, 0.05434782608695652, 0.06521739130434782, 0.07608695652173914, 0.08695652173913043, 0.09782608695652174, 0.10869565217391304, 0.11956521739130435, 0.13043478260869565, 0.14130434782608695, 0.15217391304347827, 0.16304347826086957, 0.17391304347826086, 0.18478260869565216, 0.1956521739130435, 0.20652173913043478, 0.21739130434782608, 0.22826086956521738, 0.2391304347826087, 0.25, 0.2608695652173913, 0.2717391304347826, 0.2826086956521739, 0.29347826086956524, 0.30434782608695654, 0.31521739130434784, 0.32608695652173914, 0.33695652173913043, 0.34782608695652173, 0.358695652173913, 0.3695652173913043, 0.3804347826086957, 0.391304347826087, 0.40217391304347827, 0.41304347826086957, 0.42391304347826086, 0.43478260869565216, 0.44565217391304346, 0.45652173913043476, 0.4673913043478261, 0.4782608695652174, 0.4891304347826087, 0.5, 0.5108695652173914, 0.5217391304347826, 0.532608695652174, 0.5434782608695652, 0.5543478260869565, 0.5652173913043478, 0.5760869565217391, 0.5869565217391305, 0.5978260869565217, 0.6086956521739131, 0.6195652173913043, 0.6304347826086957, 0.6413043478260869, 0.6521739130434783, 0.6630434782608695, 0.6739130434782609, 0.6847826086956522, 0.6956521739130435, 0.7065217391304348, 0.717391304347826, 0.7282608695652174, 0.7391304347826086, 0.75, 0.7608695652173914, 0.7717391304347826, 0.782608695652174, 0.7934782608695652, 0.8043478260869565, 0.8152173913043478, 0.8260869565217391, 0.8369565217391305, 0.8478260869565217, 0.8586956521739131, 0.8695652173913043, 0.8804347826086957, 0.8913043478260869, 0.9021739130434783, 0.9130434782608695, 0.9239130434782609, 0.9347826086956522, 0.9456521739130435, 0.9565217391304348, 0.967391304347826, 0.9782608695652174, 0.9891304347826086, 1.0], "x": [62.0, 119.0, 128.0, 147.0, 184.46, 204.3, 238.02, 264.2, 297.52, 297.52, 297.52, 301.0, 323.31, 337.0, 368.0, 379.0, 381.0, 391.0, 398.68, 399.0, 407.0, 413.99, 416.53, 437.36, 476.0, 480.0, 485.95, 493.0, 495.67, 528.0, 538.51, 541.49, 547.0, 554.0, 557.0, 563.0, 566.48, 575.0, 583.0, 585.0, 594.0, 604.96, 611.0, 618.84, 701.0, 702.0, 704.0, 728.0, 732.0, 748.0, 764.0, 786.0, 795.0, 807.0, 829.0, 833.1, 887.0, 892.56, 1020.0, 1035.4, 1080.0, 1154.0, 1232.0, 1244.0, 1400.3, 1537.0, 1549.0, 1567.0, 1585.0, 1730.0, 1775.0, 1817.0, 1827.0, 1864.0, 2001.0, 2043.0, 2439.3, 2904.0, 3220.0, 3810.0, 7020.0, 7069.0, 8830.0, 11100.0, 12760.0, 21000.0, 24700.0, 24900.0, 31140.0, 31800.0, 42680.0, 117000.0], "type": "scatter"}, {"showlegend": true, "name": "Dry year scenario <br> (BRSDM model)", "mode": "lines", "hoverinfo": "dry", "y": [0, 0.48], "x": [666, 666], "line": {"color": "#3FA0FF", "dash": "dot", "shape": "vh", "width": "4"}, "type": "scatter"}, {"showlegend": false, "name": "Dry year scenario <br> (BRSDM model)", "mode": "lines", "hoverinfo": "dry", "y": [0.48, 0.48], "x": [0, 666], "line": {"color": "#3FA0FF", "dash": "dot", "shape": "vh", "width": "4"}, "type": "scatter"}, {"showlegend": true, "name": "Normal year scenario <br> (BRSDM model)", "mode": "lines", "hoverinfo": "wet", "y": [0, 0.844], "x": [2506, 2506], "line": {"color": "#264DFF", "width": "4", "dash": "dashdot", "shape": "vh"}, "type": "scatter"}, {"showlegend": false, "name": "Normal year scenario <br> (BRSDM model)", "mode": "lines", "hoverinfo": "wet", "y": [0.844, 0.844], "x": [0, 2506], "line": {"color": "#264DFF", "width": "4", "dash": "dashdot", "shape": "vh"}, "type": "scatter"}, {"showlegend": true, "name": "Wet year scenario <br> (BRSDM model)", "mode": ...
# <script>function downloadimage(format, height, width, filename) {var p = document.getElementById('f36bd84e-3092-45ff-b640-ee34867706f1');Plotly.downloadImage(p, {format: format, height: height, width: width, filename: filename});};if(document.readyState == 'complete') {{downloadimage('png', 600, 800, 'UseCase3.1_seasonal_b');}}</script>

# %% [markdown]
# <a name="Close"></a>
# # 6. Close the SQLite connection

# %%
conn.close()

print 'Connection to SQLite engine is disconnected'
# Out:
# Connection to SQLite engine is disconnected

# %% [markdown]
# # The End :)
