# %% [markdown]
# <h2><center>WaMDaM Directions and Use Cases</center></h2>
# <h3><center>Step 1: Setup / Installation on Local Machine</center></h3>
# <h4><center>By Adel M. Abdallah, Utah State University, August 2018</center></h4>

# %% [markdown]
# # Step 1.2: Use the Wizard to load datasets to WaMDaM
#
# ### i. Download the input datasets to load them into WaMDaM
#
# <font color=red>**Warning!**</font> This step might take up to 2 days to load all the datasets one at-at-a-time, especially the two large datasets: the Idaho Flow Dataset and the Utah Flow Datasets where both have millions of records.
#
# **Alternatively**, skip this step, proceed to Step # 1.7 to work with a preloaded, populated SQLite file that we provide.
#
# Next, load data using one of three supported importers:
# i) from a WaMDaM Excel workbook template,
# ii) from the Consortium of Universities for the Advancement of Hydrologic Science, Inc. (CUAHSI) web-service, and
# iii) from the US Bureau Reclamation Water Information System (RWIS).
#
# Clone or download the use case data files from the **2Workbooks_datasets** folder in the following GitHub repository to a folder on your local machine.
#
# https://github.com/WamdamProject/WaMDaM_UseCases/tree/master/UseCases_files/2Workbooks_datasets
# The data files are Excel macro template file (.xlsm) that is WaMDaM compliant and WaterML (.wml) from the Bureau of Reclamation Information System (Table 1).
#
# The Excel template must have 19 WaMDaM needed spreadsheets and their headers. You can download the blank template at following link. Open the template and view the HomePage spreadsheet for more info on its structure and how to populate it with data
# https://github.com/WamdamProject/WaMDaM_UseCases/tree/master/UseCases_files/0WorkbookTemplates/InputData_Template
#
# ### ii. load each file into the WaMDaM database file you created in Step 1.1
#
# Click the third tab **Import Data into WaMDaM** to load the datasets in (Table 1) based on their type: Excel, USBOR file, or CUAHSI as described below.
#
# <br>
#
# **Table 1:** Data sources used in WaMDaM use cases and their expected load time to SQLite
#
#
# No.  | File name | Expected load time to SQLite | Data source name
# -- | :-- | :-- | :--
# 1 | 01_WaDE_August_2018 | ~ 5 minutes | Water Data Exchange (WaDE) Program of the   Western States Water Council http://www.westernstateswater.org/wade
# 2 | 02_Bear_Commission_August_2018 | ~ 5   minutes | Bear   River Commission Flows (Personal Communications, 2016)
# 3 | 03_BearWyomingModel_August_2018 | ~ 5   minutes | Bear   River systems Dynamics Model (BRSDM) (Sehlke and Jacobson, 2005)
# 4 | 04_WASH_August_2018 | ~ 5   minutes | Watershed   Area of Suitable Habitat model (WASH) (Alafifi and Rosenberg, In review)
# 5 | 05_WEAP_August_2018 | ~15 min | Bear River WEAP Model 2012 and 2017 for Utah   (David Rosenberg, 2017)
# 6 | 06_HyrumReservoir_curve_August_2018 | ~ 5 minutes | U.S. Bureau of Reclamation   (Gary Henrie -Personal Communications, 2016)
# 7 | 07_UtahDams_August_2018 | ~ 1 hour | Utah Dams Dataset (Craig Miller-Personal   Communications, 2016)
# 8 | 08_USDams_August2018 | ~ 1   hour | US   Major Dams Dataset (U.S. Geological Survey, 2013)
# 9 | 09_USHydropower_August_2018 | ~ 1   hour | US   Hydropower Dataset (N.M. Samu, 2017)
# 10 | 10_IdahoDiversions_August_2018 | ~ 15   hours | Idaho   Flows Dataset (Liz Cresto-Personal Communications, 2016)
# 11 | 11_Utah_FlowData_August_2018 | ~ 15 hours | Utah Flows Dataset (Craig Miller -Personal Communications,   2016)
# 12 | 12_CALVIN_August_2018 [bonus] | ~ 1 hour |  Jon Herman-Personal Communications, 2016
# 13 | 13_BOR_Hyrum_Oct27_2017.wml | ~ 5   minutes | U.S. Bureau of Reclamation Water Information system web   service https://water.usbr.gov
# 14 | 14_Shasta.wml  [bonus] | ~ 5   minutes | U.S.   Bureau of Reclamation Water Information system web service   https://water.usbr.gov
# 15 | CUAHSI sites | ~ 2 hours | WaterOneFlow Web Services (CUAHSI)   http://his.cuahsi.org/wofws.html
#
#
#
#
#
# #### i. Excel files (.xlsm)
# Click the button **From Excel**. Navigate to the folder you downloaded above, select the file 03BearWyomingModel_August_2018.xlsm, then click **Load data**. Repeat this step for the remaining .xlsm files (Table 1).
#
# #### ii. USBOR time series WaterML file
# Click the button **From Bureau of Reclamation**. Browse to select the file _BOR Hyrum Oct27 2017.wml_, and click **Load**.
#
# #### iii.	CUAHSI time series data
# Click the button **From CUAHSI** Fill out the site code, variable code, start and end dates for each site one at a time. Then, click the **Retrieve Data** button at the bottom. Next, click at **Load Into WaMDaM**
#
#
# ##### CAUHSI Time Series # 1 – Bear River at Idaho-Utah Stateline
#
# Field | Entry
# :-- | :--
# Site   Code | NWISUV:10092700 / BEAR RIVER AT   IDAHO-UTAH STATE LINE
# Variable   Code | NWISDV:00060/DataType=MEAN
# Begin   Date | 1985-09-02
# End Date | 2017-07-11
#
#
# ##### CAUHSI Time Series # 2 – Bear River near Utah-Wyoming Stateline
#
# Field | Entry
# -- | --
# Site   Code | NWISUV:10011500 / BEAR RIVER NEAR   UTAH-WYOMING STATE LINE
# Variable   Code | NWISDV:00060/DataType=MEAN
# Begin   Date | 1983-07-12
# End Date | 2017-07-11
#
#
# ##### CAUHSI Time Series # 3 – Bear River near Stewart Dam near Montpelier, ID
#
# Field | Entry
# -- | --
# Site   Code | NWISUV:10046500 / BEAR RIVER BL   STEWART DAM NR MONTPELIER, ID
# Variable   Code | NWISDV:00060/DataType=MEAN
# Begin   Date | 1942-10-01
# End Date | 1993-09-29
#
#
#
# There is also a log- text file that records all the data loading activities into the same SQLite file that you’ll find in the same directory where your WaMDaM Wizard is placed or installed.
#
# Should you have an error, share the file log- text file with the developer. The file is in the folder:
#
# > C:\Program Files\WaMDaM_v1.03_UtahStateUniversity\wamdam_log_dbName.log
#
#
# <font color=red>**Congratulations!**</font> You have finished loading the 13 water resources management datasets into a WaMDaM SQLite file.
