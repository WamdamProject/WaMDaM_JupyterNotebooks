# %% [markdown]
# ## WaMDaM_Use_Case 3.4: what are dams that have hydropower in Utah and California?
#
# #### By Adel M. Abdallah, Utah State University, August 2018
#
#
# This notebook demonstrates basic WaMDaM use cases analysis using scientific Python libraries such as [pandas](https://pandas.pydata.org/) and [plotly](https://plot.ly/).  It reads WaMDaM SQLite data from a published HydroShare Generic Resource, runs SQL script, and them uses Python plotly to visualize the results
#
# This use case identifies and compares dams and hyrdopower plants in Utah and California
#
# For more info: http://docs.wamdam.org/QuerySelect/use_case_3/#use-case-34
#
#
# ### Steps to reproduce this use case results and plots
#
# 1.[Import python libraries](#Import)
#
#
# 2.[Connect to the WaMDaM populated SQLite file](#Connect)
#
#
# 3.[Query WaMDaM dababase to compare Hydropower in Shasta and Flaming Gorge Reservoirs](#QueryCompare)
#
#
# 4.[Query WaMDaM dababase to identify Utah dams with Hydropower purpose](#QueryUtahDams)
#
#
# 5.[Query WaMDaM dababase to identify Utah power plants](#QueryUtahPowerPlants)
#
#
# 6.[Query WaMDaM dababase to identify California dams with Hydropower purpose](#QueryCaliDams)
#
#
# 7.[Query WaMDaM dababase to identify California power plants](#QueryCaliPowerPlants)
#
#
# 8.[Close the SQLite and WEAP API connections](#Close)

# %% [markdown]
# <a name="Import"></a>
# ## 1. Import python libraries
# ### Install any missing ones you dont have. How? see at this link here
# https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/

# %%
# 1. Import python libraries 
### set the notebook mode to embed the figures within the cell

import plotly
plotly.__version__
import plotly.offline as offline
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
offline.init_notebook_mode(connected=True)
from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *

init_notebook_mode(connected=True)         # initiate notebook for offline plot

import os
import csv
from collections import OrderedDict
import sqlite3
import pandas as pd
import numpy as np
from IPython.display import display, Image, SVG, Math, YouTubeVideo
import urllib

print 'The needed Python libraries have been imported'
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# imported

# %% [markdown]
# <a name="Connect"></a>
# ## 2. Connect to the WaMDaM populated SQLite file

# %%
# 2. Connect to the WaMDaM populated SQLite file 


# Then we can run queries against it within this notebook :)  

# the SQLite file is published here 
#https://github.com/WamdamProject/WaMDaM_UseCases/blob/master/UseCases_files/3SQLite_database/BearRiverDatasets_June_2018.sqlite

conn = sqlite3.connect('BearRiverDatasets_June_2018_Final.sqlite')

print 'Connected to the WaMDaM SQLite file called: BearRiverDatasets_June_2018_Final'
# Out:
# connected

# %% [markdown]
# <a name="QueryCompare"></a>
# ## 3. Query WaMDaM dababase to compare Hydropower in Shasta and Flaming Gorge Reservoirs

# %%
# 3.4 Identify_aggregate_TimeSeriesValues.csv
Query_UseCase3_4_URL="""
https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase3/UseCase3.4/2_CompareShastaFlamingGorge.sql

"""

# Read the query text inside the URL
Query_UseCase3_4_text = urllib.urlopen(Query_UseCase3_4_URL).read()


# return query result in a pandas data frame
result_df_UseCase3_4= pd.read_sql_query(Query_UseCase3_4_text, conn)

# uncomment the below line to see the list of attributes
display (result_df_UseCase3_4)

# it takes some time (maybe 10-20 seconds) to return back the result
# Out:
#   ResourceTypeAcronymDamHEIGHT  InstanceNameCVDamHEIGHT  DamHEIGHT  \
# 0                US Major Dams         Shasta Reservoir      602.0
# 1                US Major Dams  Flaming Gorge Reservoir      502.0
# 2                US Major Dams          Hyrum Reservoir      116.0
# 3                US Major Dams         Cutler Reservoir      114.0
#
#   UnitNameHeight  InstalledCapacity UnitNameCap  N_Gen
# 0           foot              714.0    Megawatt    7.0
# 1           foot              151.8    Megawatt    3.0
# 2           foot                0.5    Megawatt    1.0
# 3           foot               30.0    Megawatt    2.0

# %% [markdown]
# <a name="QueryUtahDams"></a>
# ## 4. Query WaMDaM dababase to identify Utah dams with Hydropower purpose

# %%
# 3.4 Identify_aggregate_TimeSeriesValues.csv
Query_UseCase3_4_URL="""
https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase3/UseCase3.4/1_HydroPower_UT_USDams.sql

"""

# Read the query text inside the URL
Query_UseCase3_4_text = urllib.urlopen(Query_UseCase3_4_URL).read()


# return query result in a pandas data frame
result_df_UseCase3_4= pd.read_sql_query(Query_UseCase3_4_text, conn)

# uncomment the below line to see the list of attributes
display (result_df_UseCase3_4)

# it takes some time (maybe 10-20 seconds) to return back the result
# Out:
#   ResourceTypeAcronymPurpose          InstanceNamePurpose  \
# 0              US Major Dams                      GUNLOCK
# 1              US Major Dams                       VERNON
# 2              US Major Dams                SOLDIER CREEK
# 3              US Major Dams                   DEER CREEK
# 4              US Major Dams                      WANSHIP
# 5              US Major Dams                FLAMING GORGE
# 6              US Major Dams                         ECHO
# 7              US Major Dams                     PINEVIEW
# 8              US Major Dams  UTAH POWER & LIGHT - CUTLER
#
#   CategoricalvaluePurpose ResourceTypeAcronymState  \
# 0                       H            US Major Dams
# 1                       H            US Major Dams
# 2                       H            US Major Dams
# 3                       H            US Major Dams
# 4                       H            US Major Dams
# 5                       H            US Major Dams
# 6                       H            US Major Dams
# 7                       H            US Major Dams
# 8                       H            US Major Dams
#
#              InstanceNameState FreeTextValueState
# 0                      GUNLOCK                 UT
# 1                       VERNON                 UT
# 2                SOLDIER CREEK                 UT
# 3                   DEER CREEK                 UT
# 4                      WANSHIP                 UT
# 5                FLAMING GORGE                 UT
# 6                         ECHO                 UT
# 7                     PINEVIEW                 UT
# 8  UTAH POWER & LIGHT - CUTLER                 UT

# %% [markdown]
# <a name="QueryUtahPowerPlants"></a>
# ## 5. Query WaMDaM dababase to identify Utah power plants

# %%
# 3.4 Identify_aggregate_TimeSeriesValues.csv
Query_UseCase3_4_URL="""
https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase3/UseCase3.4/3_HydroPowerPlants_UT.sql

"""

# Read the query text inside the URL
Query_UseCase3_4_text = urllib.urlopen(Query_UseCase3_4_URL).read()


# return query result in a pandas data frame
result_df_UseCase3_4= pd.read_sql_query(Query_UseCase3_4_text, conn)

# uncomment the below line to see the list of attributes
display (result_df_UseCase3_4)

# it takes some time (maybe 10-20 seconds) to return back the result
# Out:
#    ResourceTypeAcronymmState                         InstanceNameState  \
# 0                      NHAAP                           Deer Creek (UT)
# 1                      NHAAP                             Flaming Gorge
# 2                      NHAAP                              Spring Creek
# 3                      NHAAP                              Spanish Fork
# 4                      NHAAP                                    Payson
# 5                      NHAAP                                    Causey
# 6                      NHAAP                                   Wanship
# 7                      NHAAP                                   Gateway
# 8                      NHAAP                                  Olmstead
# 9                      NHAAP                                  Echo Dam
# 10                     NHAAP                             Pine View Dam
# 11                     NHAAP                                   Pioneer
# 12                     NHAAP                                Jordanelle
# 13                     NHAAP                                    Uintah
# 14                     NHAAP                                    Stairs
# 15                     NHAAP                              Lower Monroe
# 16                     NHAAP                              Upper Beaver
# 17                     NHAAP                                     Hyrum
# 18                     NHAAP                              Center Creek
# 19                     NHAAP                                     Upper
# 20                     NHAAP                                     Weber
# 21                     NHAAP                               Yellowstone
# 22                     NHAAP                      Beaver Lower Hydro 1
# 23                     NHAAP                               Snake Creek
# 24                     NHAAP                               Snake Creek
# 25                     NHAAP                               Bartholomew
# 26                     NHAAP                              Hobble Creek
# 27                     NHAAP                         Upper Bartholomew
# 28                     NHAAP                                   Boulder
# 29                     NHAAP                              Cutler Hydro
# ..                       ...                                       ...
# 44                     NHAAP                              Pigeon Creek
# 45                     NHAAP                                      Veyo
# 46                     NHAAP                                 Sand Cove
# 47                     NHAAP                                   Gunlock
# 48                     NHAAP                                Upper-Unit
# 49                     NHAAP                                    Unit 4
# 50                     NHAAP                                    Unit 3
# 51                     NHAAP                                Lower-Unit
# 52                     NHAAP                        Beaver Mid Hydro 2
# 53                     NHAAP                             Lower Boulder
# 54                     NHAAP                          Hydro Plant No 1
# 55                     NHAAP                               Pine Valley
# 56                     NHAAP                                   Granite
# 57                     NHAAP                              Brigham City
# 58                     NHAAP                                     Thayn
# 59                     NHAAP                   Sixmile Creek Diversion
# 60                     NHAAP                   Granite Creek Diversion
# 61                     NHAAP                      Pah Tempe Powerhouse
# 62                     NHAAP                  Granite Creek Powerhouse
# 63                     NHAAP                   Cherry Grove Powerhouse
# 64                     NHAAP                                Orderville
# 65                     NHAAP     DeWitt Pipeline Hydroelectric Project
# 66                     NHAAP          Big Willow Hydroelectric Project
# 67                     NHAAP                        Monroe Cold Spring
# 68                     NHAAP  Battle Creek Microhydro Power Generation
# 69                     NHAAP                                 Box Elder
# 70                     NHAAP                                 Coveville
# 71                     NHAAP                                  Richmond
# 72                     NHAAP      Ferron Water Treatment Plant Project
# 73                     NHAAP                  Alta Micro-Hydro Project
#
#    StateFreeTextValue
# 0                  UT
# 1                  UT
# 2                  UT
# 3                  UT
# 4                  UT
# 5                  UT
# 6                  UT
# 7                  UT
# 8                  UT
# 9                  UT
# 10                 UT
# 11                 UT
# 12                 UT
# 13                 UT
# 14                 UT
# 15                 UT
# 16                 UT
# 17                 UT
# 18                 UT
# 19                 UT
# 20                 UT
# 21                 UT
# 22                 UT
# 23                 UT
# 24                 UT
# 25                 UT
# 26                 UT
# 27                 UT
# 28                 UT
# 29                 UT
# ..                ...
# 44                 UT
# 45                 UT
# 46                 UT
# 47                 UT
# 48                 UT
# 49                 UT
# 50                 UT
# 51                 UT
# 52                 UT
# 53                 UT
# 54                 UT
# 55                 UT
# 56                 UT
# 57                 UT
# 58                 UT
# 59                 UT
# 60                 UT
# 61                 UT
# 62                 UT
# 63                 UT
# 64                 UT
# 65                 UT
# 66                 UT
# 67                 UT
# 68                 UT
# 69                 UT
# 70                 UT
# 71                 UT
# 72                 UT
# 73                 UT
#
# [74 rows x 3 columns]

# %% [markdown]
# <a name="QueryCaliDams"></a>
# ## 6. Query WaMDaM dababase to identify California dams with Hydropower purpose

# %%
# 3.4 Identify_aggregate_TimeSeriesValues.csv
Query_UseCase3_4_URL="""
https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase3/UseCase3.4/4_HydroPower_CA_USDams.sql

"""

# Read the query text inside the URL
Query_UseCase3_4_text = urllib.urlopen(Query_UseCase3_4_URL).read()


# return query result in a pandas data frame
result_df_UseCase3_4= pd.read_sql_query(Query_UseCase3_4_text, conn)

# uncomment the below line to see the list of attributes
display (result_df_UseCase3_4)

# it takes some time (maybe 10-20 seconds) to return back the result
# Out:
#     ResourceTypeAcronymPurpose         CategoricalvaluePurpose  \
# 0                US Major Dams                    BUCHANAN DAM
# 1                US Major Dams  SENATOR WASH - SQUAW LAKE DIKE
# 2                US Major Dams                    SENATOR WASH
# 3                US Major Dams                      SUTHERLAND
# 4                US Major Dams                   WOHLFORD LAKE
# 5                US Major Dams                   STEVENS CREEK
# 6                US Major Dams                   SANTA FELICIA
# 7                US Major Dams                       GIBRALTAR
# 8                US Major Dams                   CEDAR SPRINGS
# 9                US Major Dams                           QUAIL
# 10               US Major Dams                         PYRAMID
# 11               US Major Dams                        TERMINAL
# 12               US Major Dams                    ISABELLA DAM
# 13               US Major Dams                     SUCCESS DAM
# 14               US Major Dams                    TERMINUS DAM
# 15               US Major Dams                   PINE FLAT DAM
# 16               US Major Dams                     WISHON MAIN
# 17               US Major Dams          WISHON AUXILIARY NO. 1
# 18               US Major Dams                      COURTRIGHT
# 19               US Major Dams                      NORTH FORK
# 20               US Major Dams                      B. F. SISK
# 21               US Major Dams                 O NEILL FOREBAY
# 22               US Major Dams            BIG CREEK DAM NO. 3A
# 23               US Major Dams             BIG CREEK DAM NO. 2
# 24               US Major Dams             BIG CREEK DAM NO. 3
# 25               US Major Dams            BEAR CREEK DIVERSION
# 26               US Major Dams                         MCSWAIN
# 27               US Major Dams                  EXCHEQUER MAIN
# 28               US Major Dams                  EXCHEQUER DIKE
# 29               US Major Dams                DON PEDRO DIKE A
# ..                         ...                             ...
# 97               US Major Dams                    DRUM FOREBAY
# 98               US Major Dams            LAKE SPAULDING NO. 2
# 99               US Major Dams  LAKE SPAULDING NO. 3 AUXILIARY
# 100              US Major Dams                            BOCA
# 101              US Major Dams                       OUR HOUSE
# 102              US Major Dams                     FRENCH LAKE
# 103              US Major Dams             FAUCHERIE LAKE MAIN
# 104              US Major Dams           LAKE VALLEY AUXILIARY
# 105              US Major Dams                     BOWMAN ARCH
# 106              US Major Dams             THERMALITO AFTERBAY
# 107              US Major Dams              THERMALITO FOREBAY
# 108              US Major Dams                    FISH BARRIER
# 109              US Major Dams            THERMALITO DIVERSION
# 110              US Major Dams                        OROVILLE
# 111              US Major Dams                     STONY GORGE
# 112              US Major Dams                             POE
# 113              US Major Dams                          CRESTA
# 114              US Major Dams                 BLACK BUTTE DAM
# 115              US Major Dams                      ROCK CREEK
# 116              US Major Dams              WHISKEYTOWN DIKE 1
# 117              US Major Dams              WHISKEYTOWN DIKE 2
# 118              US Major Dams                PHILBROOK SADDLE
# 119              US Major Dams                     WHISKEYTOWN
# 120              US Major Dams                         KESWICK
# 121              US Major Dams                          SHASTA
# 122              US Major Dams                        LEWISTON
# 123              US Major Dams                         TRINITY
# 124              US Major Dams                      BOX CANYON
# 125              US Major Dams                       IRON GATE
# 126              US Major Dams                      COPCO NO 1
#
#     ResourceTypeAcronymState               InstanceNameState  \
# 0              US Major Dams                    BUCHANAN DAM
# 1              US Major Dams  SENATOR WASH - SQUAW LAKE DIKE
# 2              US Major Dams                    SENATOR WASH
# 3              US Major Dams                      SUTHERLAND
# 4              US Major Dams                   WOHLFORD LAKE
# 5              US Major Dams                   STEVENS CREEK
# 6              US Major Dams                   SANTA FELICIA
# 7              US Major Dams                       GIBRALTAR
# 8              US Major Dams                   CEDAR SPRINGS
# 9              US Major Dams                           QUAIL
# 10             US Major Dams                         PYRAMID
# 11             US Major Dams                        TERMINAL
# 12             US Major Dams                    ISABELLA DAM
# 13             US Major Dams                     SUCCESS DAM
# 14             US Major Dams                    TERMINUS DAM
# 15             US Major Dams                   PINE FLAT DAM
# 16             US Major Dams                     WISHON MAIN
# 17             US Major Dams          WISHON AUXILIARY NO. 1
# 18             US Major Dams                      COURTRIGHT
# 19             US Major Dams                      NORTH FORK
# 20             US Major Dams                      B. F. SISK
# 21             US Major Dams                 O NEILL FOREBAY
# 22             US Major Dams            BIG CREEK DAM NO. 3A
# 23             US Major Dams             BIG CREEK DAM NO. 2
# 24             US Major Dams             BIG CREEK DAM NO. 3
# 25             US Major Dams            BEAR CREEK DIVERSION
# 26             US Major Dams                         MCSWAIN
# 27             US Major Dams                  EXCHEQUER MAIN
# 28             US Major Dams                  EXCHEQUER DIKE
# 29             US Major Dams                DON PEDRO DIKE A
# ..                       ...                             ...
# 97             US Major Dams                    DRUM FOREBAY
# 98             US Major Dams            LAKE SPAULDING NO. 2
# 99             US Major Dams  LAKE SPAULDING NO. 3 AUXILIARY
# 100            US Major Dams                            BOCA
# 101            US Major Dams                       OUR HOUSE
# 102            US Major Dams                     FRENCH LAKE
# 103            US Major Dams             FAUCHERIE LAKE MAIN
# 104            US Major Dams           LAKE VALLEY AUXILIARY
# 105            US Major Dams                     BOWMAN ARCH
# 106            US Major Dams             THERMALITO AFTERBAY
# 107            US Major Dams              THERMALITO FOREBAY
# 108            US Major Dams                    FISH BARRIER
# 109            US Major Dams            THERMALITO DIVERSION
# 110            US Major Dams                        OROVILLE
# 111            US Major Dams                     STONY GORGE
# 112            US Major Dams                             POE
# 113            US Major Dams                          CRESTA
# 114            US Major Dams                 BLACK BUTTE DAM
# 115            US Major Dams                      ROCK CREEK
# 116            US Major Dams              WHISKEYTOWN DIKE 1
# 117            US Major Dams              WHISKEYTOWN DIKE 2
# 118            US Major Dams                PHILBROOK SADDLE
# 119            US Major Dams                     WHISKEYTOWN
# 120            US Major Dams                         KESWICK
# 121            US Major Dams                          SHASTA
# 122            US Major Dams                        LEWISTON
# 123            US Major Dams                         TRINITY
# 124            US Major Dams                      BOX CANYON
# 125            US Major Dams                       IRON GATE
# 126            US Major Dams                      COPCO NO 1
#
#     FreeTextValueState
# 0                   CA
# 1                   CA
# 2                   CA
# 3                   CA
# 4                   CA
# 5                   CA
# 6                   CA
# 7                   CA
# 8                   CA
# 9                   CA
# 10                  CA
# 11                  CA
# 12                  CA
# 13                  CA
# 14                  CA
# 15                  CA
# 16                  CA
# 17                  CA
# 18                  CA
# 19                  CA
# 20                  CA
# 21                  CA
# 22                  CA
# 23                  CA
# 24                  CA
# 25                  CA
# 26                  CA
# 27                  CA
# 28                  CA
# 29                  CA
# ..                 ...
# 97                  CA
# 98                  CA
# 99                  CA
# 100                 CA
# 101                 CA
# 102                 CA
# 103                 CA
# 104                 CA
# 105                 CA
# 106                 CA
# 107                 CA
# 108                 CA
# 109                 CA
# 110                 CA
# 111                 CA
# 112                 CA
# 113                 CA
# 114                 CA
# 115                 CA
# 116                 CA
# 117                 CA
# 118                 CA
# 119                 CA
# 120                 CA
# 121                 CA
# 122                 CA
# 123                 CA
# 124                 CA
# 125                 CA
# 126                 CA
#
# [127 rows x 5 columns]

# %% [markdown]
# <a name="QueryCaliPowerPlants"></a>
# ## 7.Query WaMDaM dababase to identify California power plants

# %%
# 3.4 Identify_aggregate_TimeSeriesValues.csv
Query_UseCase3_4_URL="""
https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/4Queries_SQL/UseCase3/UseCase3.4/5_HydroPowerPlants_CA.sql

"""

# Read the query text inside the URL
Query_UseCase3_4_text = urllib.urlopen(Query_UseCase3_4_URL).read()


# return query result in a pandas data frame
result_df_UseCase3_4= pd.read_sql_query(Query_UseCase3_4_text, conn)

# uncomment the below line to see the list of attributes
display (result_df_UseCase3_4)

# it takes some time (maybe 10-20 seconds) to return back the result
# Out:
#     ResourceTypeAcronymmState                         InstanceNameState  \
# 0                       NHAAP                                    Folsom
# 1                       NHAAP                              Judge F Carr
# 2                       NHAAP                                  Lewiston
# 3                       NHAAP                                   Keswick
# 4                       NHAAP                               New Melones
# 5                       NHAAP                                    Nimbus
# 6                       NHAAP                                    ONeill
# 7                       NHAAP                                Parker Dam
# 8                       NHAAP                              W R Gianelli
# 9                       NHAAP                                    Shasta
# 10                      NHAAP                              Spring Creek
# 11                      NHAAP                                  Stampede
# 12                      NHAAP                                   Trinity
# 13                      NHAAP                                    Drop 1
# 14                      NHAAP                               Drop 2 (CA)
# 15                      NHAAP                               Drop 3 (CA)
# 16                      NHAAP                                    Drop 4
# 17                      NHAAP                                    Drop 5
# 18                      NHAAP                                Pilot Knob
# 19                      NHAAP                            Monticello Dam
# 20                      NHAAP                               Whiskeytown
# 21                      NHAAP                     Friant Hydro Facility
# 22                      NHAAP       Friant Fishwater Release Powerhouse
# 23                      NHAAP                Madera Canal (Site 980 65)
# 24                      NHAAP                               Stony Gorge
# 25                      NHAAP         Madera Canal Mile 24.2 Powerhouse
# 26                      NHAAP                                 High Line
# 27                      NHAAP                   Siphon Drop Power Plant
# 28                      NHAAP             Kings River Siphon Powerhouse
# 29                      NHAAP                              Senator Wash
# ..                        ...                                       ...
# 383                     NHAAP                  Lincoln Metering Station
# 384                     NHAAP            Sandhill Water Treatment Plant
# 385                     NHAAP                         Tank 4 In-Conduit
# 386                     NHAAP                                  Carlsbad
# 387                     NHAAP             Eagle Mountain Pumped Storage
# 388                     NHAAP                                    Tank 7
# 389                     NHAAP   Gibraltar Conduit Hydroelectric Project
# 390                     NHAAP                           Tennessee Ditch
# 391                     NHAAP                                    CHYDRO
# 392                     NHAAP                                    Tank 3
# 393                     NHAAP          Rock Creek Water Treatment Plant
# 394                     NHAAP   Tanner In-Conduit Hydroelectric Project
# 395                     NHAAP  Waterman Turnout In-Conduit Hydroelectri
# 396                     NHAAP                            Foxglove Check
# 397                     NHAAP                             Newside Check
# 398                     NHAAP                          Rockwood Heading
# 399                     NHAAP                            Tuberose Check
# 400                     NHAAP                                  Westside
# 401                     NHAAP                              Central Main
# 402                     NHAAP                                   Check 8
# 403                     NHAAP                              Dahlia Check
# 404                     NHAAP                                    Drop 2
# 405                     NHAAP                            Fillaree Check
# 406                     NHAAP           Loma Rica Hydroelectric Station
# 407                     NHAAP           Plant 134 Hydroelectric Project
# 408                     NHAAP  M7W Pressure Reducing Station Hydroelect
# 409                     NHAAP  Perdue Water Treatment Plant Hydroelectr
# 410                     NHAAP  Roemer Water Filtration Facility Hydroel
# 411                     NHAAP          Deep Creek Hydroelectric Project
# 412                     NHAAP        Ione Hydroelectric Station Project
#
#     StateFreeTextValue
# 0                   CA
# 1                   CA
# 2                   CA
# 3                   CA
# 4                   CA
# 5                   CA
# 6                   CA
# 7                   CA
# 8                   CA
# 9                   CA
# 10                  CA
# 11                  CA
# 12                  CA
# 13                  CA
# 14                  CA
# 15                  CA
# 16                  CA
# 17                  CA
# 18                  CA
# 19                  CA
# 20                  CA
# 21                  CA
# 22                  CA
# 23                  CA
# 24                  CA
# 25                  CA
# 26                  CA
# 27                  CA
# 28                  CA
# 29                  CA
# ..                 ...
# 383                 CA
# 384                 CA
# 385                 CA
# 386                 CA
# 387                 CA
# 388                 CA
# 389                 CA
# 390                 CA
# 391                 CA
# 392                 CA
# 393                 CA
# 394                 CA
# 395                 CA
# 396                 CA
# 397                 CA
# 398                 CA
# 399                 CA
# 400                 CA
# 401                 CA
# 402                 CA
# 403                 CA
# 404                 CA
# 405                 CA
# 406                 CA
# 407                 CA
# 408                 CA
# 409                 CA
# 410                 CA
# 411                 CA
# 412                 CA
#
# [413 rows x 3 columns]

# %% [markdown]
# <a name="Close"></a>
# # 8. Close the SQLite aconnection

# %%
conn.close()

print 'Connection to SQLite engine is disconnected'
# Out:
# Sqlite connection disconnected

# %% [markdown]
# # The End :)
