# %% [markdown]
# # Use Case 2: How does connectivity of natural and built infrastructure components compare in a particular area across datasets?
#
# #### By Adel M. Abdallah, Utah State University, August 2018
#
# This notebook demonstrates basic WaMDaM use cases analysis using scientific Python libraries such as [pandas](https://pandas.pydata.org/) and [plotly](https://plot.ly/).  It reads WaMDaM SQLite data from a published HydroShare Generic Resource, runs SQL script, and them uses Python plotly to visualize the results
#
#
# Execute the following cells by pressing `Shift-Enter`, or by pressing the play button
# <img style='display:inline;padding-bottom:15px' src='play-button.png'>
# on the toolbar above.
#
#
#
# This use case identifies three models connectives for Hyrum Reservoir, UT
#
#   <img src="https://github.com/WamdamProject/WaMDaM-software-ecosystem/blob/master/mkdocs/Edit_MD_Files/QuerySelect/images/networks.png?raw=true" style="float:center">
#   <h3><center>**Figure x:** WaMDaM Paper</center></h3>
#
#
# ### Steps to reproduce this use case results and plots
#
# 1. [Import python libraries](#Import)
#
# 2. [Connect to the WaMDaM populated SQLite file](#Connect)
#
# 3. [Get network connections at Hyrum Reservoir, Utah](#NetworkAtHyrum)
#
# 4. [Get network connections at Hyrum Reservoir, Utah](#NetworkAtHyrum)
#
# 5. [Get network connections at Bear River Migratory Bird Refuge, Utah](#NetworkAtRefuge)
#
# 6. [Get network connections at Shasta Reservoir, California](#NetworkAtShasta)
#
# 7. [Close the SQLite connection](#Close)

# %% [markdown]
# <a name="Import"></a>
# # 1. Import python libraries

# %%
# 1. Import python libraries 

import os
import csv
from collections import OrderedDict
import sqlite3
import pandas as pd
import numpy as np
from IPython.display import display, Image, SVG, Math, YouTubeVideo
import urllib

print 'The libraries are imported'
# Out:
# The libraries are imported

# %% [markdown]
# <a name="Connect"></a>
# # 2. Connect to the WaMDaM populated SQLite file

# %%
# 2. Connect to the WaMDaM populated SQLite file 

# Then we can run queries against it within this notebook :)  

# the SQLite file is published here 


WaMDaM_SQLite_Name='BearRiverDatasets_August2018.sqlite'


conn = sqlite3.connect(WaMDaM_SQLite_Name)

print 'Connected to the WaMDaM SQLite file called'+': '+ WaMDaM_SQLite_Name
# Out:
# Connected to the WaMDaM SQLite file called: BearRiverDatasets_August2018.sqlite

# %% [markdown]
# <a name="NetworkAtHyrum"></a>
# # 3. Get network connctions at Hyrum Reservoir, Utah

# %%
# Get network connctions at Hyrum Reservoir, Utah

Query_connect_URL="""
https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/4_Queries_SQL/UseCase2/1_FindNodeLinkInstances_Hyrum.sql
"""
# Read the query text inside the URL
Query_connect_text = urllib.urlopen(Query_connect_URL).read()
# return query result in a pandas data frame
result_df_connect= pd.read_sql_query(Query_connect_text, conn)

# print the dataframe to inspect it    
# display (result_df_connect) 

# Save the datafrom as a csv file into the Jupyter notebook working space
result_df_connect.to_csv('UseCases_Results_csv\Hyrum_connect.csv', index = False)


display (result_df_connect)

print "Queries are done"
# Out:
#    ResourceTypeAcronym                ScenarioName  \
# 0     Diversion                                        j29           -111.860
# 1     Diversion                                        j29           -111.860
# 2     Diversion                                        j29           -111.860
# 3        Stream                                        j29           -111.860
# 4        Stream                                        j32           -111.821
# 5   Return flow                                        j41           -111.769
# 6   Return flow                                        j42           -111.822
# 7        Stream                            Hyrum Reservoir           -111.858
# 8        Stream                            Hyrum Reservoir           -111.858
# 9        Stream                            Hyrum Reservoir           -111.858
# 10       Stream                            Hyrum Reservoir           -111.858
# 11       Stream                            Hyrum Reservoir           -111.858
# 12       Stream                            Hyrum Reservoir           -111.858
# 13       Stream                            Hyrum Reservoir           -111.858
# 14       Stream                            Hyrum Reservoir           -111.858
# 15       Stream                            Hyrum Reservoir           -111.858
# 16       Stream                            Hyrum Reservoir           -111.858
# 17       Stream                            Hyrum Reservoir           -111.858
# 18       Stream                            Hyrum Reservoir           -111.858
# 19       Stream  Blacksmith Fork to Hyrum Reservoir Inflow           -111.858
# 20       Stream  Blacksmith Fork to Hyrum Reservoir Inflow           -111.858
# 21       Stream  Blacksmith Fork to Hyrum Reservoir Inflow           -111.858
# 22    Diversion                            Hyrum Reservoir           -111.858
# 23    Diversion                            Hyrum Reservoir           -111.858
# 24    Diversion                            Hyrum Reservoir           -111.858
# 25    Diversion                            Hyrum Reservoir           -111.858
# 26    Diversion                            Hyrum Reservoir           -111.858
# 27    Diversion                            Hyrum Reservoir           -111.858
# 28  Return flow                             Paradise Canal           -111.743
# 29  Return flow                             Paradise Canal           -111.743
# 30  Return flow                             Paradise Canal           -111.743
# 31  Return flow                                Hyrum Canal           -111.805
# 32  Return flow                                Hyrum Canal           -111.805
# 33  Return flow                                Hyrum Canal           -111.805
# 34       Stream        South Fork Little Bear River Inflow           -111.828
# 35       Stream        South Fork Little Bear River Inflow           -111.828
# 36       Stream        South Fork Little Bear River Inflow           -111.828
# 37       Stream        South Fork Little Bear River Inflow           -111.828
# 38       Stream        South Fork Little Bear River Inflow           -111.828
# 39       Stream        South Fork Little Bear River Inflow           -111.828
# 40       Stream                            Hyrum Reservoir           -111.858
# 41       Stream                            Hyrum Reservoir           -111.858
# 42       Stream                            Hyrum Reservoir           -111.858
# 43       Stream                            Hyrum Reservoir           -111.858
# 44       Stream                            Hyrum Reservoir           -111.858
# 45       Stream                            Hyrum Reservoir           -111.858
# 46    Diversion                            Hyrum Reservoir           -111.858
# 47    Diversion                            Hyrum Reservoir           -111.858
# 48    Diversion                            Hyrum Reservoir           -111.858
# 49    Diversion                            Hyrum Reservoir           -111.858
# 50    Diversion                            Hyrum Reservoir           -111.858
# 51    Diversion                            Hyrum Reservoir           -111.858
# 52    Diversion                            Hyrum Reservoir           -111.858
# 53    Diversion                            Hyrum Reservoir           -111.858
# 54    Diversion                            Hyrum Reservoir           -111.858
#
#     StartLatitude_y StartNodeObjectType              EndNodeInstance  \
# 0          41.62030                   v                          j27
# 1          41.62030                   v                          j28
# 2          41.62030                   v                          j44
# 3          41.62030                   v                          j24
# 4          41.52790                   j                          j29
# 5          41.58900                 dem                          j29
# 6          41.59900                 dem                          j29
# 7          41.62220           Reservoir           Return Flow Node 4
# 8          41.62220           Reservoir           Return Flow Node 4
# 9          41.62220           Reservoir           Return Flow Node 4
# 10         41.62220           Reservoir           Return Flow Node 4
# 11         41.62220           Reservoir           Return Flow Node 4
# 12         41.62220           Reservoir           Return Flow Node 4
# 13         41.62220           Reservoir           Return Flow Node 4
# 14         41.62220           Reservoir           Return Flow Node 4
# 15         41.62220           Reservoir           Return Flow Node 4
# 16         41.62220           Reservoir           Return Flow Node 4
# 17         41.62220           Reservoir           Return Flow Node 4
# 18         41.62220           Reservoir           Return Flow Node 4
# 19         41.59038    Tributary Inflow              Hyrum Reservoir
# 20         41.59038    Tributary Inflow              Hyrum Reservoir
# 21         41.59038    Tributary Inflow              Hyrum Reservoir
# 22         41.62220           Reservoir              South Cache New
# 23         41.62220           Reservoir              South Cache New
# 24         41.62220           Reservoir              South Cache New
# 25         41.62220           Reservoir         South Cache Existing
# 26         41.62220           Reservoir         South Cache Existing
# 27         41.62220           Reservoir         South Cache Existing
# 28         41.58088         Demand Site              Hyrum Reservoir
# 29         41.58088         Demand Site              Hyrum Reservoir
# 30         41.58088         Demand Site              Hyrum Reservoir
# 31         41.58186         Demand Site              Hyrum Reservoir
# 32         41.58186         Demand Site              Hyrum Reservoir
# 33         41.58186         Demand Site              Hyrum Reservoir
# 34         41.53568    Tributary Inflow              Hyrum Reservoir
# 35         41.53568    Tributary Inflow              Hyrum Reservoir
# 36         41.53568    Tributary Inflow              Hyrum Reservoir
# 37         41.53568    Tributary Inflow              Hyrum Reservoir
# 38         41.53568    Tributary Inflow              Hyrum Reservoir
# 39         41.53568    Tributary Inflow              Hyrum Reservoir
# 40         41.62220           Reservoir           Return Flow Node 4
# 41         41.62220           Reservoir           Return Flow Node 4
# 42         41.62220           Reservoir           Return Flow Node 4
# 43         41.62220           Reservoir           Return Flow Node 4
# 44         41.62220           Reservoir           Return Flow Node 4
# 45         41.62220           Reservoir           Return Flow Node 4
# 46         41.62220           Reservoir          South Cache Potable
# 47         41.62220           Reservoir          South Cache Potable
# 48         41.62220           Reservoir          South Cache Potable
# 49         41.62220           Reservoir  Wellsville East Field Canal
# 50         41.62220           Reservoir  Wellsville East Field Canal
# 51         41.62220           Reservoir  Wellsville East Field Canal
# 52         41.62220           Reservoir      Wellsville Mendon Canal
# 53         41.62220           Reservoir      Wellsville Mendon Canal
# 54         41.62220           Reservoir      Wellsville Mendon Canal
#
#     EndStartInstanceLong  EndLatitude_y EndNodeObjectType
# 0               -111.862       41.67800               dem
# 1               -111.898       41.68200               dem
# 2               -111.962       41.63200               dem
# 3               -111.946       41.74290                 j
# 4               -111.860       41.62030                 v
# 5               -111.860       41.62030                 v
# 6               -111.860       41.62030                 v
# 7               -111.944       41.73282  Return Flow Node
# 8               -111.944       41.73282  Return Flow Node
# 9               -111.944       41.73282  Return Flow Node
# 10              -111.944       41.73282  Return Flow Node
# 11              -111.944       41.73282  Return Flow Node
# 12              -111.944       41.73282  Return Flow Node
# 13              -111.944       41.73282  Return Flow Node
# 14              -111.944       41.73282  Return Flow Node
# 15              -111.944       41.73282  Return Flow Node
# 16              -111.944       41.73282  Return Flow Node
# 17              -111.944       41.73282  Return Flow Node
# 18              -111.944       41.73282  Return Flow Node
# 19              -111.858       41.62220         Reservoir
# 20              -111.858       41.62220         Reservoir
# 21              -111.858       41.62220         Reservoir
# 22              -111.854       41.67218       Demand Site
# 23              -111.854       41.67218       Demand Site
# 24              -111.854       41.67218       Demand Site
# 25              -111.884       41.67925       Demand Site
# 26              -111.884       41.67925       Demand Site
# 27              -111.884       41.67925       Demand Site
# 28              -111.858       41.62220         Reservoir
# 29              -111.858       41.62220         Reservoir
# 30              -111.858       41.62220         Reservoir
# 31              -111.858       41.62220         Reservoir
# 32              -111.858       41.62220         Reservoir
# 33              -111.858       41.62220         Reservoir
# 34              -111.858       41.62220         Reservoir
# 35              -111.858       41.62220         Reservoir
# 36              -111.858       41.62220         Reservoir
# 37              -111.858       41.62220         Reservoir
# 38              -111.858       41.62220         Reservoir
# 39              -111.858       41.62220         Reservoir
# 40              -111.944       41.73282  Return Flow Node
# 41              -111.944       41.73282  Return Flow Node
# 42              -111.944       41.73282  Return Flow Node
# 43              -111.944       41.73282  Return Flow Node
# 44              -111.944       41.73282  Return Flow Node
# 45              -111.944       41.73282  Return Flow Node
# 46              -111.864       41.66848       Demand Site
# 47              -111.864       41.66848       Demand Site
# 48              -111.864       41.66848       Demand Site
# 49              -111.897       41.68027       Demand Site
# 50              -111.897       41.68027       Demand Site
# 51              -111.897       41.68027       Demand Site
# 52              -111.967       41.65253       Demand Site
# 53              -111.967       41.65253       Demand Site
# 54              -111.967       41.65253       Demand Site
# Queries are done

# %% [markdown]
# ## add text to interpret tables

# %% [markdown]
# <a name="Reproduce"></a>
# # 4. Reproduce the plot above?

# %% [markdown]
# #### Use Microsoft Visio or any other charting software like Lucidchart to plot the node of interest and all the lines that connet to it.
#
# #### Group each plot per the ResourceType (source) and Scenario
#
# ![](https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/UseCases_files/8Figures_jpg/UseCase2.PNG)

# %% [markdown]
# <a name="NetworkAtRefuge"></a>
# # 5. Get network connctions at Bear River Migratory Bird Refuge, Utah
#
# <font color=green>Bonus use case not reported in the WaMDaM paper</font>

# %%
# query connectivity at the Bear River Migratory Bird Refuge, Utah
Query_connect_URL="""
https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/4_Queries_SQL/UseCase2/2_FindNodeLinkInstances_refuge.sql
"""
# Read the query text inside the URL
Query_connect_text = urllib.urlopen(Query_connect_URL).read()
# return query result in a pandas data frame
result_df_connect= pd.read_sql_query(Query_connect_text, conn)

# print the dataframe to inspect it    
# display (result_df_connect) 

# Save the datafrom as a csv file into the Jupyter notebook working space
result_df_connect.to_csv('UseCases_Results_csv\BirdRefuge_connect.csv', index = False)

display (result_df_connect)


print "Queries are done"
# Out:
#    ResourceTypeAcronym                ScenarioName  \
# 0                 WASH     base case scenario 2003
# 1                 WASH     base case scenario 2003
# 2                 WEAP  Bear River WEAP Model 2010
# 3                 WEAP  Bear River WEAP Model 2010
# 4                 WEAP  Bear River WEAP Model 2010
# 5                 WEAP  Bear River WEAP Model 2010
# 6                 WEAP  Bear River WEAP Model 2010
# 7                 WEAP  Bear River WEAP Model 2010
# 8                 WEAP  Bear River WEAP Model 2010
# 9                 WEAP  Bear River WEAP Model 2010
# 10                WEAP  Bear River WEAP Model 2010
# 11                WEAP  Bear River WEAP Model 2010
# 12                WEAP  Bear River WEAP Model 2017
# 13                WEAP  Bear River WEAP Model 2017
# 14                WEAP  Bear River WEAP Model 2017
# 15                WEAP  Bear River WEAP Model 2017
#
#                                      LinkInstanceName     LinkObjectType  \
# 0                                              j20j21       envSiteExist
# 1                                              j21j23       envSiteExist
# 2   Return Flow from Bird Refuge to Return Flow No...        Return Flow
# 3   Return Flow from Bird Refuge to Return Flow No...        Return Flow
# 4   Blacksmith Fork to Hyrum Reservoir from Blacks...        River Reach
# 5   Blacksmith Fork to Hyrum Reservoir from Blacks...        River Reach
# 6   Blacksmith Fork to Hyrum Reservoir from Blacks...        River Reach
# 7   Blacksmith Fork to Hyrum Reservoir from Blacks...        River Reach
# 8   Transmission Link from Withdrawal Node 1 to Bi...  Transmission Link
# 9   Transmission Link from Withdrawal Node 1 to Bi...  Transmission Link
# 10  Transmission Link from Withdrawal Node 1 to Bi...  Transmission Link
# 11  Transmission Link from Withdrawal Node 1 to Bi...  Transmission Link
# 12  Transmission Link from Withdrawal Node 1 to Bi...  Transmission Link
# 13  Transmission Link from Withdrawal Node 1 to Bi...  Transmission Link
# 14  Transmission Link from Withdrawal Node 1 to Bi...  Transmission Link
# 15  Transmission Link from Withdrawal Node 1 to Bi...  Transmission Link
#
#    ObjectTypeCV       StartEndNode  StartInstanceLong  StartLatitude_y  \
# 0        Stream                j20           -112.117         41.58610
# 1        Stream                j21           -112.143         41.49100
# 2   Return flow        Bird Refuge           -112.177         41.42575
# 3   Return flow        Bird Refuge           -112.177         41.42575
# 4        Stream  Withdrawal Node 1           -112.177         41.44894
# 5        Stream  Withdrawal Node 1           -112.177         41.44894
# 6        Stream  Withdrawal Node 1           -112.177         41.44894
# 7        Stream  Withdrawal Node 1           -112.177         41.44894
# 8     Diversion  Withdrawal Node 1           -112.177         41.44894
# 9     Diversion  Withdrawal Node 1           -112.177         41.44894
# 10    Diversion  Withdrawal Node 1           -112.177         41.44894
# 11    Diversion  Withdrawal Node 1           -112.177         41.44894
# 12    Diversion  Withdrawal Node 1           -112.177         41.44894
# 13    Diversion  Withdrawal Node 1           -112.177         41.44894
# 14    Diversion  Withdrawal Node 1           -112.177         41.44894
# 15    Diversion  Withdrawal Node 1           -112.177         41.44894
#
#    StartNodeObjectType     EndNodeInstance  EndStartInstanceLong  \
# 0                    j                 j21              -112.143
# 1                    j                 j23              -112.222
# 2          Demand Site  Return Flow Node 1              -112.226
# 3          Demand Site  Return Flow Node 1              -112.226
# 4     River Withdrawal         Bird Refuge              -112.177
# 5     River Withdrawal         Bird Refuge              -112.177
# 6     River Withdrawal         Bird Refuge              -112.177
# 7     River Withdrawal         Bird Refuge              -112.177
# 8     River Withdrawal         Bird Refuge              -112.177
# 9     River Withdrawal         Bird Refuge              -112.177
# 10    River Withdrawal         Bird Refuge              -112.177
# 11    River Withdrawal         Bird Refuge              -112.177
# 12    River Withdrawal         Bird Refuge              -112.177
# 13    River Withdrawal         Bird Refuge              -112.177
# 14    River Withdrawal         Bird Refuge              -112.177
# 15    River Withdrawal         Bird Refuge              -112.177
#
#     EndLatitude_y EndNodeObjectType
# 0        41.49100                 j
# 1        41.47470                 j
# 2        41.41716  Return Flow Node
# 3        41.41716  Return Flow Node
# 4        41.42575       Demand Site
# 5        41.42575       Demand Site
# 6        41.42575       Demand Site
# 7        41.42575       Demand Site
# 8        41.42575       Demand Site
# 9        41.42575       Demand Site
# 10       41.42575       Demand Site
# 11       41.42575       Demand Site
# 12       41.42575       Demand Site
# 13       41.42575       Demand Site
# 14       41.42575       Demand Site
# 15       41.42575       Demand Site
# Queries are done

# %% [markdown]
# ## add text to interpret tables

# %% [markdown]
# <a name="NetworkAtShasta"></a>
# # 6. Get network connctions at Shasta Reservoir, California
# <font color=green>Bonus use case not reported in the WaMDaM paper</font>

# %%
# Get network connctions at Shasta Reservoir, California	

# query connectivity at the Shasta Reservoir, California
Query_connect_URL="""
https://raw.githubusercontent.com/WamdamProject/WaMDaM_UseCases/master/4_Queries_SQL/UseCase2/3_FindNodeLinkInstances_Shasta.sql
"""
# Read the query text inside the URL
Query_connect_text = urllib.urlopen(Query_connect_URL).read()
# return query result in a pandas data frame
result_df_connect= pd.read_sql_query(Query_connect_text, conn)

# print the dataframe to inspect it    
# display (result_df_connect) 

# Save the datafrom as a csv file into the Jupyter notebook working space
result_df_connect.to_csv('UseCases_Results_csv\Shasta_connect.csv', index = False)


display (result_df_connect)

print "Queries are done"
# Out:
#   ResourceTypeAcronym ScenarioName LinkInstanceName LinkObjectType  \
# 0              CALVIN    Base Case        SR_SHA,D5    Calvin Link
#
#   ObjectTypeCV StartEndNode  StartInstanceLong  StartLatitude_y  \
# 0         None       SR_SHA          40.716872      -122.418122
#
#   StartNodeObjectType EndNodeInstance  EndStartInstanceLong  EndLatitude_y  \
# 0     Surface Storage              D5             40.612004    -122.446023
#
#   EndNodeObjectType
# 0          Junction
# Queries are done

# %% [markdown]
# <a name="Close"></a>
# # 7. Close the SQLite connection

# %%
conn.close()

print 'connection disconnected'

# %% [markdown]
# # The End :)  Congratulations!
